# %%
from glob import glob
import os, cv2, json
import numpy as np
from PIL import Image

# %%
def mask2bbox_dictionary(path):
    ds_dict = [] # dictionary containing all bboxes in the train/val dataset
    masks_list = glob(f"{path}/*") #get all masks
    counter = 0 #new mask id
    
    for m in masks_list:
        im_dict =[]
        # load segmentation mask
        mask = np.array(Image.open(m))
        filename = os.path.basename(m).replace("mask", "image")
        path_name = m.replace("mask", "image").replace("labels", "images")
        obj_ids = np.unique(mask)
        obj_ids = obj_ids[0:]
        #each layer refers to one class
        masks = mask == obj_ids[:, None, None]

        # each mask layer refers to a class
        for layer in range(masks.shape[0]):
            # find the threshold in that layer
            thresh = cv2.threshold(masks[layer].astype(np.uint8),0,1,cv2.THRESH_BINARY)[1]
            # get boundary contours for the objects
            contours = cv2.findContours(thresh.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            contours = contours[0] if len(contours) == 2 else contours[1]
            c = []
            l = []
            for cntr in contours:
                x,y,w,h = cv2.boundingRect(cntr)
                if w > 15 and h > 15:
                    c.append([x,y,(x+w),(y+h)])
                    
            # get the dict to save each file annot
            file_dict = {"annotations":{
                         "bbox":c,
                         "bbx_mode":1,
                         "category_id":layer},
                         "file_name": path_name,
                         "height": 500,
                         "width":500,
                         "image_id" :counter}
            ds_dict.append(file_dict)
        counter+=1
    return ds_dict

# %%
fold1_path = "/data/weed_data/kfold_5ds/1/labels/"
bbox_dictionary = mask2bbox_dictionary(fold1_path)
bbox_dictionary
# Out:
# [{'annotations': {'bbox': [[0, 467, 71, 500],
#     [2, 438, 27, 459],
#     [469, 345, 495, 365],
#     [206, 257, 246, 298],
#     [117, 185, 181, 217],
#     [238, 153, 259, 170],
#     [10, 147, 67, 231],
#     [69, 136, 172, 195],
#     [242, 118, 258, 135],
#     [157, 100, 190, 126],
#     [450, 94, 500, 148],
#     [229, 85, 258, 112],
#     [385, 74, 448, 119],
#     [411, 51, 438, 72]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0060_image_11.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 0},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0060_image_11.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 0},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_f13be7a9a337c096aca2_image_10.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 1},
#  {'annotations': {'bbox': [[122, 298, 147, 336],
#     [212, 293, 236, 346],
#     [162, 291, 189, 342],
#     [35, 276, 54, 336],
#     [329, 266, 370, 321],
#     [64, 252, 141, 359],
#     [429, 251, 479, 328],
#     [0, 213, 39, 322],
#     [207, 211, 237, 260],
#     [149, 202, 215, 308],
#     [33, 184, 61, 236],
#     [483, 150, 500, 167],
#     [295, 92, 466, 324]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_f13be7a9a337c096aca2_image_10.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 1},
#  {'annotations': {'bbox': [[344, 400, 420, 480],
#     [204, 349, 260, 420],
#     [379, 328, 417, 384]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_f13be7a9a337c096aca2_image_10.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 1},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_e3a6e5bc547705dbcdcb_image_9.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 2},
#  {'annotations': {'bbox': [[449, 337, 479, 358],
#     [286, 306, 326, 353],
#     [261, 255, 387, 310],
#     [283, 216, 334, 258],
#     [352, 189, 380, 211],
#     [336, 109, 375, 145],
#     [266, 48, 402, 121],
#     [65, 16, 85, 34]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_e3a6e5bc547705dbcdcb_image_9.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 2},
#  {'annotations': {'bbox': [[0, 335, 28, 372]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_e3a6e5bc547705dbcdcb_image_9.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 2},
#  {'annotations': {'bbox': [[479, 481, 500, 500],
#     [480, 461, 500, 480],
#     [459, 414, 500, 450],
#     [474, 384, 490, 404],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_80dd39fbf30de56c350f_image_3.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 3},
#  {'annotations': {'bbox': [[428, 479, 452, 500],
#     [300, 443, 328, 500],
#     [236, 432, 286, 500],
#     [74, 376, 108, 420],
#     [175, 356, 192, 379],
#     [379, 355, 396, 377],
#     [434, 274, 500, 500],
#     [394, 272, 460, 361],
#     [14, 189, 31, 211],
#     [348, 147, 372, 187],
#     [266, 113, 289, 166],
#     [393, 104, 420, 147],
#     [46, 71, 68, 126],
#     [28, 69, 148, 227],
#     [293, 67, 353, 241],
#     [468, 51, 500, 104],
#     [430, 38, 500, 203]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_80dd39fbf30de56c350f_image_3.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 3},
#  {'annotations': {'bbox': [[365, 437, 384, 460],
#     [353, 428, 372, 446],
#     [418, 384, 493, 429],
#     [438, 186, 458, 210],
#     [390, 177, 413, 212],
#     [467, 170, 499, 193],
#     [408, 168, 430, 209],
#     [72, 0, 408, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0083_image_37.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 4},
#  {'annotations': {'bbox': [[0, 361, 231, 500],
#     [166, 237, 330, 404],
#     [0, 192, 107, 287],
#     [258, 0, 500, 500],
#     [0, 0, 264, 188]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0083_image_37.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 4},
#  {'annotations': {'bbox': [[0, 246, 130, 389], [0, 107, 96, 241]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0083_image_37.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 4},
#  {'annotations': {'bbox': [[384, 454, 408, 483],
#     [328, 448, 353, 470],
#     [356, 400, 372, 416],
#     [115, 385, 169, 412],
#     [203, 32, 220, 55],
#     [121, 0, 166, 20],
#     [19, 0, 78, 32],
#     [0, 0, 27, 18]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0075_image_31.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 5},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0075_image_31.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 5},
#  {'annotations': {'bbox': [[462, 122, 500, 168],
#     [422, 115, 453, 136],
#     [475, 0, 500, 56],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_01190df9563e3951106f_image_0.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 6},
#  {'annotations': {'bbox': [[447, 475, 468, 493],
#     [457, 444, 500, 500],
#     [59, 272, 124, 320],
#     [405, 227, 458, 276],
#     [336, 200, 380, 256],
#     [6, 157, 188, 310],
#     [393, 93, 412, 110],
#     [400, 78, 500, 197],
#     [199, 64, 240, 87],
#     [287, 63, 484, 233],
#     [464, 58, 491, 91],
#     [360, 42, 380, 60],
#     [294, 29, 340, 70],
#     [332, 24, 369, 69],
#     [401, 18, 449, 58],
#     [431, 0, 500, 70],
#     [86, 0, 166, 48]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_01190df9563e3951106f_image_0.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 6},
#  {'annotations': {'bbox': [[307, 437, 336, 464],
#     [314, 424, 368, 440],
#     [454, 422, 496, 449],
#     [43, 420, 60, 438],
#     [341, 398, 370, 416],
#     [309, 354, 339, 376],
#     [329, 255, 348, 271],
#     [81, 207, 155, 253],
#     [266, 205, 296, 226],
#     [333, 201, 486, 288],
#     [192, 201, 231, 225],
#     [378, 156, 406, 210],
#     [353, 76, 376, 97],
#     [176, 61, 206, 103],
#     [445, 28, 464, 49],
#     [227, 20, 281, 70],
#     [125, 19, 157, 36],
#     [158, 0, 207, 60],
#     [0, 0, 61, 40]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0068_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 7},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0068_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 7},
#  {'annotations': {'bbox': [[265, 474, 285, 490],
#     [141, 444, 160, 464],
#     [57, 420, 77, 454],
#     [0, 390, 26, 416],
#     [0, 264, 500, 500],
#     [163, 263, 215, 296],
#     [214, 262, 230, 280],
#     [178, 247, 204, 264],
#     [412, 53, 500, 186],
#     [39, 0, 413, 157]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0032_image_0.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 8},
#  {'annotations': {'bbox': [[370, 471, 426, 500],
#     [0, 358, 342, 500],
#     [0, 0, 500, 400]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0032_image_0.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 8},
#  {'annotations': {'bbox': [[118, 455, 148, 477],
#     [73, 433, 114, 464],
#     [459, 371, 495, 393],
#     [386, 318, 406, 348],
#     [364, 314, 500, 500],
#     [477, 294, 500, 342],
#     [0, 266, 152, 500],
#     [112, 255, 158, 308],
#     [483, 69, 500, 87],
#     [276, 18, 376, 101],
#     [425, 0, 500, 52],
#     [307, 0, 337, 26],
#     [253, 0, 288, 33],
#     [176, 0, 254, 56]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0053_image_38.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 9},
#  {'annotations': {'bbox': [[398, 460, 421, 476],
#     [422, 399, 500, 500],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0053_image_38.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 9},
#  {'annotations': {'bbox': [[171, 443, 192, 461],
#     [436, 385, 455, 403],
#     [4, 329, 110, 423],
#     [281, 323, 299, 353],
#     [295, 316, 401, 430],
#     [387, 305, 500, 417],
#     [144, 298, 160, 314],
#     [107, 296, 244, 415],
#     [318, 260, 334, 280],
#     [149, 190, 168, 206],
#     [308, 158, 366, 192],
#     [357, 141, 378, 158],
#     [323, 134, 352, 157],
#     [164, 117, 188, 135],
#     [464, 113, 481, 129],
#     [475, 98, 500, 124],
#     [351, 74, 373, 104],
#     [373, 64, 389, 85],
#     [16, 23, 55, 41],
#     [414, 6, 436, 35],
#     [444, 0, 500, 41],
#     [112, 0, 367, 301],
#     [97, 0, 116, 16],
#     [25, 0, 91, 48]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0060_image_26.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 10},
#  {'annotations': {'bbox': [[197, 78, 260, 125],
#     [278, 0, 331, 30],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0060_image_26.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 10},
#  {'annotations': {'bbox': [[388, 435, 408, 452],
#     [0, 428, 32, 475],
#     [368, 419, 389, 436],
#     [349, 386, 385, 416],
#     [5, 385, 31, 419],
#     [375, 378, 443, 404],
#     [19, 372, 41, 388],
#     [301, 321, 324, 337],
#     [444, 317, 487, 342],
#     [407, 315, 445, 351],
#     [62, 300, 137, 362],
#     [359, 278, 402, 301],
#     [405, 277, 452, 297],
#     [346, 250, 390, 282],
#     [433, 246, 500, 298],
#     [239, 205, 268, 221],
#     [404, 201, 450, 226],
#     [349, 152, 418, 184],
#     [405, 145, 482, 204],
#     [63, 118, 91, 141],
#     [91, 101, 119, 122],
#     [465, 68, 500, 163],
#     [434, 58, 485, 112],
#     [367, 6, 412, 40],
#     [0, 0, 388, 243],
#     [0, 0, 24, 24]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0077_image_9.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 11},
#  {'annotations': {'bbox': [[476, 132, 500, 151],
#     [0, 0, 500, 500],
#     [0, 0, 216, 217]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0077_image_9.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 11},
#  {'annotations': {'bbox': [[380, 479, 411, 500],
#     [307, 467, 347, 500],
#     [66, 436, 90, 468],
#     [434, 374, 500, 500],
#     [9, 304, 25, 323],
#     [437, 250, 454, 269],
#     [161, 246, 188, 264],
#     [256, 219, 307, 258],
#     [336, 165, 368, 181],
#     [151, 160, 247, 256],
#     [388, 139, 408, 160],
#     [348, 124, 368, 149],
#     [256, 124, 277, 145],
#     [288, 88, 306, 110],
#     [345, 63, 364, 80],
#     [283, 34, 310, 53],
#     [147, 24, 282, 99],
#     [182, 0, 313, 26]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0044_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 12},
#  {'annotations': {'bbox': [[474, 405, 500, 493], [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0044_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 12},
#  {'annotations': {'bbox': [[207, 395, 500, 500],
#     [0, 387, 173, 500],
#     [95, 314, 122, 332],
#     [246, 267, 264, 287],
#     [223, 264, 249, 284],
#     [0, 0, 500, 314]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0079_image_61.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 13},
#  {'annotations': {'bbox': [[351, 483, 375, 500],
#     [0, 207, 500, 500],
#     [452, 54, 496, 74],
#     [346, 8, 375, 40],
#     [298, 0, 328, 17],
#     [0, 0, 284, 179]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0079_image_61.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 13},
#  {'annotations': {'bbox': [[360, 0, 500, 36]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0079_image_61.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 13},
#  {'annotations': {'bbox': [[264, 470, 280, 489],
#     [180, 460, 209, 492],
#     [266, 398, 301, 429],
#     [118, 354, 154, 418],
#     [176, 154, 203, 183],
#     [82, 152, 112, 185],
#     [126, 120, 170, 155],
#     [171, 75, 242, 124],
#     [242, 37, 306, 176],
#     [104, 0, 500, 500],
#     [0, 0, 91, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f2_id_A_19_treat_1_image_2.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 14},
#  {'annotations': {'bbox': [[207, 320, 230, 345], [40, 0, 328, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f2_id_A_19_treat_1_image_2.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 14},
#  {'annotations': {'bbox': [[255, 132, 336, 248]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f2_id_A_19_treat_1_image_2.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 14},
#  {'annotations': {'bbox': [], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0088_image_55.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 15},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0088_image_55.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 15},
#  {'annotations': {'bbox': [[186, 375, 246, 415],
#     [33, 331, 128, 432],
#     [417, 0, 453, 22]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0021_image_53.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 16},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0021_image_53.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 16},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_F_13_treat_1_image_13.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 17},
#  {'annotations': {'bbox': [[0, 387, 38, 495],
#     [79, 342, 161, 436],
#     [83, 278, 129, 333],
#     [0, 174, 22, 244],
#     [83, 74, 165, 270],
#     [0, 12, 40, 108]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_F_13_treat_1_image_13.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 17},
#  {'annotations': {'bbox': [[157, 132, 203, 184]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_F_13_treat_1_image_13.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 17},
#  {'annotations': {'bbox': [[418, 452, 444, 478],
#     [236, 65, 262, 118],
#     [242, 52, 266, 74],
#     [333, 50, 403, 97],
#     [271, 14, 297, 64],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0042_image_50.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 18},
#  {'annotations': {'bbox': [[0, 422, 39, 500],
#     [370, 380, 500, 500],
#     [281, 0, 500, 210],
#     [60, 0, 129, 37]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0042_image_50.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 18},
#  {'annotations': {'bbox': [[117, 0, 388, 382], [0, 0, 64, 162]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0042_image_50.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 18},
#  {'annotations': {'bbox': [[0, 444, 31, 500],
#     [0, 344, 46, 452],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_b91036bc9bfae789e060_image_11.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 19},
#  {'annotations': {'bbox': [[3, 464, 22, 500],
#     [0, 316, 114, 500],
#     [338, 251, 362, 280],
#     [97, 101, 129, 155],
#     [74, 90, 96, 130],
#     [427, 79, 487, 97],
#     [307, 36, 350, 54],
#     [125, 0, 152, 58],
#     [0, 0, 26, 77]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_b91036bc9bfae789e060_image_11.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 19},
#  {'annotations': {'bbox': [[413, 466, 442, 496],
#     [449, 465, 470, 481],
#     [423, 428, 446, 451],
#     [436, 418, 454, 459],
#     [462, 417, 500, 474],
#     [390, 400, 415, 416],
#     [0, 259, 312, 500],
#     [0, 252, 19, 280],
#     [443, 105, 461, 126],
#     [462, 100, 500, 130],
#     [468, 77, 484, 94],
#     [132, 21, 148, 38],
#     [465, 17, 500, 54],
#     [400, 0, 473, 50],
#     [281, 0, 385, 70]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0025_image_64.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 20},
#  {'annotations': {'bbox': [[156, 463, 227, 500],
#     [0, 376, 140, 500],
#     [18, 368, 38, 386],
#     [141, 354, 203, 372],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0025_image_64.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 20},
#  {'annotations': {'bbox': [[450, 0, 500, 31], [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_d08952daff13cd28e34d_image_0.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 21},
#  {'annotations': {'bbox': [[340, 473, 402, 500],
#     [289, 472, 336, 500],
#     [237, 472, 261, 500],
#     [122, 456, 157, 488],
#     [112, 365, 211, 456],
#     [205, 352, 246, 384],
#     [268, 332, 297, 362],
#     [294, 299, 313, 321],
#     [120, 285, 148, 317],
#     [40, 256, 176, 399],
#     [152, 242, 196, 282],
#     [160, 208, 251, 276],
#     [210, 206, 254, 233],
#     [171, 176, 229, 213],
#     [132, 174, 182, 203],
#     [411, 8, 440, 42],
#     [432, 0, 500, 86]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_d08952daff13cd28e34d_image_0.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 21},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_blank9_image_0.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 22},
#  {'annotations': {'bbox': [[309, 236, 443, 500],
#     [123, 224, 300, 500],
#     [445, 208, 500, 500],
#     [22, 8, 57, 56],
#     [456, 4, 500, 136],
#     [312, 4, 416, 234],
#     [144, 4, 288, 216]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_blank9_image_0.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 22},
#  {'annotations': {'bbox': [[212, 4, 294, 83]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_blank9_image_0.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 22},
#  {'annotations': {'bbox': [[0, 181, 24, 240], [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_1860431da694e5869161_image_9.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 23},
#  {'annotations': {'bbox': [[0, 414, 24, 468],
#     [474, 404, 500, 474],
#     [46, 377, 72, 439],
#     [479, 376, 500, 398],
#     [0, 356, 45, 419],
#     [31, 350, 47, 375],
#     [300, 343, 382, 420],
#     [300, 315, 348, 360],
#     [354, 301, 402, 347],
#     [71, 184, 108, 235],
#     [0, 124, 45, 315],
#     [375, 0, 415, 27],
#     [306, 0, 362, 64],
#     [272, 0, 308, 45],
#     [167, 0, 189, 32],
#     [64, 0, 93, 37]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_1860431da694e5869161_image_9.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 23},
#  {'annotations': {'bbox': [[0, 170, 31, 232], [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_3d9a5ad6c5e0d0db1979_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 24},
#  {'annotations': {'bbox': [[410, 479, 429, 500],
#     [473, 433, 500, 462],
#     [160, 391, 180, 426],
#     [90, 376, 120, 434],
#     [127, 310, 153, 336],
#     [297, 282, 326, 299],
#     [30, 276, 65, 344],
#     [30, 186, 396, 430],
#     [0, 172, 101, 303],
#     [91, 166, 132, 230],
#     [114, 153, 138, 192],
#     [420, 0, 454, 53],
#     [407, 0, 436, 18],
#     [232, 0, 260, 33]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_3d9a5ad6c5e0d0db1979_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 24},
#  {'annotations': {'bbox': [[78, 125, 104, 167],
#     [0, 108, 57, 194],
#     [43, 12, 71, 77]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_3d9a5ad6c5e0d0db1979_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 24},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_a3b3814c5fbc4c6b83ca_image_7.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 25},
#  {'annotations': {'bbox': [[107, 218, 142, 245],
#     [183, 209, 265, 306],
#     [167, 193, 187, 249]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_a3b3814c5fbc4c6b83ca_image_7.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 25},
#  {'annotations': {'bbox': [[14, 444, 39, 463],
#     [347, 393, 363, 409],
#     [356, 370, 372, 388],
#     [173, 182, 218, 227],
#     [233, 149, 259, 183],
#     [108, 149, 150, 187],
#     [80, 148, 97, 172],
#     [7, 135, 24, 154],
#     [216, 96, 234, 115],
#     [57, 41, 78, 60],
#     [322, 17, 339, 38]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0003_image_11.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 26},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0003_image_11.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 26},
#  {'annotations': {'bbox': [[202, 482, 225, 500],
#     [161, 475, 201, 498],
#     [48, 452, 126, 500],
#     [145, 446, 161, 466],
#     [340, 434, 372, 459],
#     [23, 358, 48, 390],
#     [46, 342, 82, 378],
#     [106, 315, 154, 338],
#     [45, 224, 108, 271],
#     [0, 40, 500, 469],
#     [460, 16, 480, 43],
#     [157, 0, 185, 26]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0046_image_31.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 27},
#  {'annotations': {'bbox': [[396, 352, 416, 372],
#     [308, 332, 343, 349],
#     [460, 323, 500, 345],
#     [448, 276, 500, 308],
#     [463, 259, 491, 277],
#     [0, 153, 500, 500],
#     [228, 79, 247, 102],
#     [0, 0, 500, 130]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0046_image_31.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 27},
#  {'annotations': {'bbox': [], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0009_image_47.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 28},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0009_image_47.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 28},
#  {'annotations': {'bbox': [[0, 384, 16, 408],
#     [130, 359, 166, 388],
#     [0, 292, 232, 500],
#     [414, 85, 500, 207],
#     [0, 59, 58, 147],
#     [139, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/id_g2_2_131_image.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 29},
#  {'annotations': {'bbox': [[451, 470, 500, 500],
#     [138, 463, 218, 500],
#     [0, 456, 82, 500],
#     [449, 432, 488, 456],
#     [301, 354, 367, 404],
#     [0, 326, 108, 463],
#     [405, 321, 424, 340],
#     [7, 112, 25, 128],
#     [233, 0, 500, 424],
#     [0, 0, 395, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/id_g2_2_131_image.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 29},
#  {'annotations': {'bbox': [[183, 477, 206, 500],
#     [187, 460, 208, 476],
#     [251, 435, 288, 500],
#     [402, 388, 420, 422],
#     [210, 384, 246, 412],
#     [241, 365, 257, 394],
#     [418, 360, 448, 410],
#     [241, 334, 278, 356],
#     [193, 270, 234, 295],
#     [0, 196, 228, 500],
#     [245, 61, 272, 100]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0100_image_58.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 30},
#  {'annotations': {'bbox': [[69, 468, 131, 500],
#     [78, 362, 108, 393],
#     [0, 330, 23, 363],
#     [37, 319, 65, 346],
#     [23, 319, 42, 337],
#     [0, 295, 16, 314],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0100_image_58.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 30},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_a0750d98d40fc39e2a16_image_7.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 31},
#  {'annotations': {'bbox': [[269, 483, 285, 500],
#     [0, 392, 26, 416],
#     [402, 329, 434, 371],
#     [451, 269, 490, 305],
#     [384, 259, 500, 382],
#     [9, 258, 44, 288],
#     [144, 238, 171, 257],
#     [176, 230, 209, 247],
#     [153, 181, 199, 228],
#     [45, 180, 99, 283],
#     [225, 177, 257, 201],
#     [264, 164, 300, 187],
#     [188, 76, 236, 113],
#     [36, 60, 165, 241],
#     [323, 46, 375, 102],
#     [267, 16, 304, 50],
#     [354, 12, 377, 30],
#     [311, 9, 364, 58],
#     [295, 8, 314, 24],
#     [444, 0, 476, 22]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_a0750d98d40fc39e2a16_image_7.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 31},
#  {'annotations': {'bbox': [[185, 256, 215, 281],
#     [156, 221, 176, 248],
#     [280, 205, 310, 237],
#     [317, 150, 343, 179],
#     [284, 128, 308, 161]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_a0750d98d40fc39e2a16_image_7.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 31},
#  {'annotations': {'bbox': [], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0024_image_33.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 32},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0024_image_33.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 32},
#  {'annotations': {'bbox': [[268, 462, 290, 486],
#     [225, 297, 248, 313],
#     [23, 292, 43, 318],
#     [313, 257, 330, 281],
#     [190, 240, 210, 256],
#     [82, 45, 98, 62],
#     [56, 33, 79, 59],
#     [168, 26, 231, 72],
#     [453, 24, 481, 42],
#     [0, 10, 43, 78],
#     [440, 0, 468, 17]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0091_image_29.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 33},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0091_image_29.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 33},
#  {'annotations': {'bbox': [[369, 346, 388, 366],
#     [482, 320, 500, 378],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_7ba6b49612b531562018_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 34},
#  {'annotations': {'bbox': [[442, 456, 500, 500],
#     [400, 442, 456, 487],
#     [482, 435, 500, 455],
#     [348, 429, 369, 446],
#     [37, 420, 167, 500],
#     [352, 401, 391, 452],
#     [449, 334, 469, 356],
#     [0, 322, 17, 352],
#     [300, 294, 500, 428],
#     [323, 244, 387, 333],
#     [211, 143, 398, 264],
#     [142, 41, 165, 57],
#     [96, 31, 146, 71],
#     [168, 25, 190, 44],
#     [60, 0, 169, 30]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_7ba6b49612b531562018_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 34},
#  {'annotations': {'bbox': [[456, 177, 500, 199],
#     [445, 128, 500, 154],
#     [360, 70, 421, 106],
#     [460, 56, 500, 99]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_7ba6b49612b531562018_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 34},
#  {'annotations': {'bbox': [[21, 7, 51, 29], [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_E_17_treat_1_image_15.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 35},
#  {'annotations': {'bbox': [[43, 268, 64, 289],
#     [36, 137, 108, 247],
#     [31, 0, 125, 88]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_E_17_treat_1_image_15.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 35},
#  {'annotations': {'bbox': [[0, 0, 52, 77]], 'bbx_mode': 1, 'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_E_17_treat_1_image_15.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 35},
#  {'annotations': {'bbox': [[294, 392, 334, 412],
#     [199, 381, 274, 429],
#     [248, 372, 273, 396],
#     [404, 344, 422, 364],
#     [205, 305, 224, 322],
#     [0, 291, 45, 318],
#     [165, 274, 193, 314],
#     [178, 262, 198, 291],
#     [309, 257, 436, 400],
#     [377, 244, 425, 268],
#     [435, 239, 500, 286],
#     [475, 215, 500, 234],
#     [376, 204, 442, 236],
#     [318, 192, 367, 234],
#     [299, 180, 345, 197],
#     [454, 176, 471, 206],
#     [371, 127, 419, 172],
#     [476, 126, 499, 143],
#     [456, 122, 480, 146],
#     [355, 120, 392, 167],
#     [0, 72, 236, 328],
#     [216, 52, 343, 196],
#     [14, 34, 33, 55],
#     [0, 25, 29, 76],
#     [405, 22, 431, 48],
#     [256, 18, 308, 52],
#     [310, 1, 327, 17]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0038_image_17.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 36},
#  {'annotations': {'bbox': [[0, 177, 40, 257],
#     [0, 144, 27, 169],
#     [0, 116, 16, 138],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0038_image_17.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 36},
#  {'annotations': {'bbox': [[0, 309, 129, 395],
#     [0, 144, 18, 161],
#     [0, 141, 133, 199],
#     [0, 0, 500, 425]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0006_image_40.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 37},
#  {'annotations': {'bbox': [[484, 242, 500, 300],
#     [302, 233, 442, 352],
#     [0, 57, 500, 500],
#     [240, 0, 500, 108],
#     [0, 0, 201, 41]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0006_image_40.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 37},
#  {'annotations': {'bbox': [[198, 356, 222, 379],
#     [295, 352, 363, 407],
#     [383, 348, 432, 409],
#     [410, 317, 500, 426],
#     [482, 301, 500, 332],
#     [295, 292, 315, 320],
#     [63, 284, 195, 419],
#     [364, 276, 383, 313],
#     [0, 242, 64, 288],
#     [440, 238, 475, 269],
#     [15, 219, 47, 242]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0059_image_27.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 38},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0059_image_27.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 38},
#  {'annotations': {'bbox': [[0, 261, 94, 382], [0, 189, 49, 252]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0059_image_27.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 38},
#  {'annotations': {'bbox': [[203, 474, 267, 500],
#     [297, 390, 313, 412],
#     [310, 377, 358, 425],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_d1c09a66b0cd55e580ce_image_10.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 39},
#  {'annotations': {'bbox': [[0, 398, 37, 445],
#     [152, 320, 422, 500],
#     [42, 233, 78, 271],
#     [10, 206, 43, 234],
#     [209, 177, 232, 200],
#     [366, 115, 411, 149],
#     [365, 0, 498, 153]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_d1c09a66b0cd55e580ce_image_10.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 39},
#  {'annotations': {'bbox': [[339, 336, 356, 352],
#     [178, 134, 206, 155],
#     [0, 48, 500, 366],
#     [7, 0, 24, 17]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0064_image_52.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 40},
#  {'annotations': {'bbox': [[0, 198, 500, 500],
#     [316, 187, 366, 209],
#     [0, 78, 29, 117],
#     [28, 0, 500, 188]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0064_image_52.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 40},
#  {'annotations': {'bbox': [[0, 0, 29, 111]], 'bbx_mode': 1, 'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0064_image_52.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 40},
#  {'annotations': {'bbox': [[410, 302, 431, 318], [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_E_4_treat_1_image_14.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 41},
#  {'annotations': {'bbox': [[424, 468, 440, 487],
#     [271, 436, 340, 500],
#     [403, 372, 500, 494],
#     [75, 355, 165, 500],
#     [387, 211, 500, 369],
#     [250, 180, 326, 348],
#     [11, 142, 38, 163],
#     [388, 94, 485, 209],
#     [440, 0, 460, 23],
#     [38, 0, 207, 324]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_E_4_treat_1_image_14.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 41},
#  {'annotations': {'bbox': [[240, 62, 317, 126]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_E_4_treat_1_image_14.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 41},
#  {'annotations': {'bbox': [[292, 465, 351, 500],
#     [435, 418, 500, 474],
#     [445, 407, 472, 423],
#     [89, 276, 121, 301],
#     [170, 260, 189, 278],
#     [403, 239, 433, 258],
#     [454, 220, 480, 244],
#     [296, 185, 337, 225],
#     [247, 163, 267, 187],
#     [143, 156, 160, 175],
#     [71, 148, 323, 271],
#     [49, 144, 82, 207],
#     [483, 8, 500, 27]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0080_image_64.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 42},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0080_image_64.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 42},
#  {'annotations': {'bbox': [[0, 383, 111, 450],
#     [396, 378, 418, 394],
#     [93, 366, 114, 392],
#     [196, 362, 219, 392],
#     [135, 359, 174, 400],
#     [102, 354, 130, 386],
#     [370, 248, 411, 284],
#     [389, 204, 448, 234],
#     [393, 173, 456, 198],
#     [407, 126, 436, 148],
#     [375, 113, 392, 133],
#     [458, 108, 496, 138],
#     [325, 81, 347, 97],
#     [385, 20, 404, 36],
#     [411, 13, 433, 52],
#     [433, 0, 500, 104]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0017_image_39.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 43},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0017_image_39.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 43},
#  {'annotations': {'bbox': [[353, 448, 390, 469],
#     [22, 432, 52, 470],
#     [41, 424, 60, 445],
#     [357, 370, 500, 500],
#     [440, 352, 483, 373],
#     [410, 347, 436, 367],
#     [404, 306, 489, 355],
#     [480, 296, 500, 320],
#     [284, 292, 328, 335],
#     [422, 276, 442, 298],
#     [115, 275, 136, 296],
#     [213, 272, 261, 316],
#     [353, 267, 375, 288],
#     [0, 262, 138, 366],
#     [103, 241, 131, 277],
#     [116, 234, 139, 264],
#     [10, 115, 26, 132],
#     [458, 97, 500, 123],
#     [39, 39, 86, 80],
#     [48, 33, 69, 54],
#     [479, 0, 500, 29],
#     [73, 0, 460, 250]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0019_image_8.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 44},
#  {'annotations': {'bbox': [[245, 98, 343, 121],
#     [378, 48, 397, 70],
#     [234, 23, 272, 61],
#     [344, 3, 361, 20],
#     [294, 1, 376, 60],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0019_image_8.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 44},
#  {'annotations': {'bbox': [[386, 448, 423, 482],
#     [434, 420, 482, 480],
#     [331, 414, 369, 447],
#     [382, 397, 400, 416],
#     [228, 359, 320, 474],
#     [283, 266, 306, 285],
#     [160, 255, 257, 324],
#     [108, 239, 125, 256],
#     [433, 136, 452, 152],
#     [208, 99, 225, 118],
#     [0, 95, 29, 159],
#     [0, 87, 442, 265]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0057_image_39.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 45},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0057_image_39.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 45},
#  {'annotations': {'bbox': [[138, 202, 222, 285]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0057_image_39.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 45},
#  {'annotations': {'bbox': [[81, 400, 125, 436],
#     [333, 348, 350, 365],
#     [155, 314, 172, 341],
#     [208, 304, 334, 441],
#     [360, 287, 499, 431],
#     [0, 286, 116, 455],
#     [149, 285, 165, 313],
#     [281, 281, 317, 298]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0059_image_30.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 46},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0059_image_30.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 46},
#  {'annotations': {'bbox': [[321, 424, 342, 441],
#     [203, 375, 312, 437],
#     [330, 366, 347, 382],
#     [319, 364, 415, 433],
#     [401, 353, 452, 401],
#     [0, 353, 217, 468],
#     [251, 330, 274, 349],
#     [357, 156, 389, 175],
#     [120, 146, 137, 167],
#     [414, 145, 435, 168],
#     [451, 141, 468, 159],
#     [388, 132, 421, 159],
#     [34, 116, 50, 132],
#     [39, 62, 68, 86],
#     [444, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0082_image_43.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 47},
#  {'annotations': {'bbox': [[0, 0, 472, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0082_image_43.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 47},
#  {'annotations': {'bbox': [[152, 455, 239, 500],
#     [474, 302, 492, 320],
#     [446, 276, 468, 324],
#     [399, 212, 423, 233],
#     [281, 212, 312, 229],
#     [233, 175, 264, 197],
#     [88, 117, 113, 136],
#     [0, 114, 423, 364],
#     [47, 93, 78, 129]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0067_image_29.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 48},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0067_image_29.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 48},
#  {'annotations': {'bbox': [[60, 460, 76, 479],
#     [10, 451, 38, 486],
#     [38, 448, 56, 473],
#     [443, 333, 461, 349],
#     [281, 313, 297, 330],
#     [173, 271, 196, 352],
#     [0, 265, 500, 500],
#     [438, 94, 472, 114],
#     [223, 92, 349, 237],
#     [456, 75, 485, 92],
#     [299, 55, 358, 111],
#     [0, 54, 144, 267],
#     [43, 35, 100, 72],
#     [429, 21, 453, 57],
#     [384, 18, 414, 74],
#     [171, 4, 212, 40],
#     [458, 0, 500, 76],
#     [212, 0, 254, 26],
#     [94, 0, 153, 37]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0098_image_17.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 49},
#  {'annotations': {'bbox': [[0, 412, 136, 500],
#     [276, 384, 292, 401],
#     [76, 367, 94, 384],
#     [114, 361, 169, 391],
#     [0, 322, 24, 346],
#     [0, 231, 32, 250],
#     [0, 211, 43, 229],
#     [0, 197, 24, 216],
#     [250, 0, 500, 394]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0098_image_17.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 49},
#  {'annotations': {'bbox': [[0, 0, 456, 379]], 'bbx_mode': 1, 'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0098_image_17.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 49},
#  {'annotations': {'bbox': [[318, 398, 396, 441],
#     [157, 318, 175, 337],
#     [23, 190, 82, 230],
#     [196, 158, 219, 180],
#     [169, 157, 500, 428],
#     [176, 143, 214, 168],
#     [155, 122, 190, 144]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0094_image_62.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 50},
#  {'annotations': {'bbox': [[58, 253, 500, 500],
#     [447, 236, 464, 256],
#     [0, 0, 500, 267]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0094_image_62.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 50},
#  {'annotations': {'bbox': [[0, 156, 217, 500]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0094_image_62.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 50},
#  {'annotations': {'bbox': [[140, 141, 160, 171],
#     [152, 127, 184, 167],
#     [127, 112, 144, 140],
#     [162, 61, 188, 94],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_1586e2d312937fc3fa15_image_7.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 51},
#  {'annotations': {'bbox': [[265, 479, 282, 496],
#     [382, 448, 412, 490],
#     [299, 420, 366, 500],
#     [457, 402, 500, 484],
#     [334, 398, 365, 439],
#     [23, 291, 56, 337],
#     [148, 261, 170, 284],
#     [56, 199, 97, 252],
#     [0, 163, 66, 303],
#     [54, 110, 82, 131],
#     [0, 84, 55, 174],
#     [276, 81, 322, 124],
#     [322, 76, 384, 160],
#     [355, 55, 379, 100],
#     [303, 52, 321, 94],
#     [330, 36, 356, 75],
#     [484, 11, 500, 38],
#     [67, 0, 252, 274]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_1586e2d312937fc3fa15_image_7.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 51},
#  {'annotations': {'bbox': [[0, 192, 28, 220],
#     [12, 44, 66, 114],
#     [116, 0, 142, 20]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_1586e2d312937fc3fa15_image_7.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 51},
#  {'annotations': {'bbox': [[359, 68, 400, 119], [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_7c860fe65829bcbbf5bf_image_11.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 52},
#  {'annotations': {'bbox': [[324, 120, 341, 146],
#     [295, 0, 475, 158],
#     [11, 0, 96, 128]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_7c860fe65829bcbbf5bf_image_11.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 52},
#  {'annotations': {'bbox': [[0, 454, 17, 500],
#     [227, 439, 292, 499],
#     [79, 439, 120, 500],
#     [122, 417, 182, 495],
#     [269, 409, 324, 478],
#     [302, 378, 336, 431],
#     [371, 369, 456, 454],
#     [375, 300, 416, 352]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_7c860fe65829bcbbf5bf_image_11.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 52},
#  {'annotations': {'bbox': [[202, 477, 231, 500],
#     [197, 390, 230, 424],
#     [238, 384, 310, 442],
#     [315, 288, 332, 306],
#     [12, 257, 40, 287],
#     [424, 232, 442, 248],
#     [305, 229, 337, 256],
#     [158, 214, 182, 253],
#     [0, 203, 500, 437],
#     [441, 36, 460, 52],
#     [184, 30, 203, 50],
#     [271, 0, 487, 83],
#     [0, 0, 51, 33]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0077_image_51.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 53},
#  {'annotations': {'bbox': [[0, 302, 500, 500], [0, 0, 500, 340]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0077_image_51.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 53},
#  {'annotations': {'bbox': [[426, 330, 446, 350],
#     [426, 296, 500, 369],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_f3046239bfd6db6cab0f_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 54},
#  {'annotations': {'bbox': [[330, 432, 346, 452],
#     [228, 425, 260, 447],
#     [303, 422, 334, 464],
#     [235, 373, 310, 426],
#     [232, 324, 276, 377],
#     [0, 319, 39, 360],
#     [45, 242, 140, 380],
#     [351, 199, 500, 452],
#     [328, 191, 352, 218],
#     [356, 186, 411, 219],
#     [0, 167, 135, 262],
#     [97, 150, 124, 190],
#     [0, 127, 21, 153],
#     [243, 83, 289, 121],
#     [191, 60, 244, 111],
#     [288, 53, 317, 90],
#     [16, 45, 251, 179],
#     [308, 23, 348, 49],
#     [254, 4, 290, 43],
#     [466, 0, 500, 17],
#     [380, 0, 453, 44],
#     [343, 0, 382, 37],
#     [144, 0, 271, 82]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_f3046239bfd6db6cab0f_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 54},
#  {'annotations': {'bbox': [[398, 200, 431, 250],
#     [400, 137, 430, 183],
#     [324, 137, 367, 192]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_f3046239bfd6db6cab0f_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 54},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_259d87e3cee18f714de7_image_9.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 55},
#  {'annotations': {'bbox': [[0, 244, 21, 280],
#     [102, 218, 122, 240],
#     [270, 200, 474, 348],
#     [356, 80, 384, 114],
#     [179, 79, 228, 120],
#     [319, 58, 351, 104],
#     [138, 55, 364, 259],
#     [89, 7, 202, 149]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_259d87e3cee18f714de7_image_9.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 55},
#  {'annotations': {'bbox': [[82, 460, 140, 493],
#     [0, 460, 45, 500],
#     [478, 438, 500, 478],
#     [22, 378, 48, 398],
#     [478, 336, 500, 373],
#     [467, 278, 499, 298],
#     [25, 220, 42, 237],
#     [1, 177, 42, 199]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0056_image_7.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 56},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0056_image_7.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 56},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_ce2f55bef78e5991543a_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 57},
#  {'annotations': {'bbox': [[110, 349, 136, 373],
#     [142, 343, 193, 386],
#     [127, 318, 147, 339],
#     [150, 312, 180, 337],
#     [271, 204, 321, 256],
# ...
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0095_image_62.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 407},
#  {'annotations': {'bbox': [[281, 481, 320, 500],
#     [267, 464, 292, 482],
#     [43, 448, 220, 500],
#     [431, 303, 449, 321],
#     [377, 270, 407, 288],
#     [332, 236, 354, 266],
#     [115, 228, 136, 244]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0007_image_17.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 408},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0007_image_17.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 408},
#  {'annotations': {'bbox': [[188, 433, 205, 455],
#     [165, 401, 196, 418],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_A_18_treat_10_image_3.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 409},
#  {'annotations': {'bbox': [[108, 481, 147, 500],
#     [0, 443, 56, 500],
#     [182, 272, 204, 295],
#     [0, 236, 68, 424],
#     [0, 216, 16, 233],
#     [253, 123, 280, 151],
#     [0, 91, 29, 118],
#     [238, 86, 263, 138],
#     [90, 64, 240, 500],
#     [109, 0, 153, 44]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_A_18_treat_10_image_3.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 409},
#  {'annotations': {'bbox': [[277, 309, 299, 329],
#     [185, 280, 294, 380],
#     [81, 197, 110, 222],
#     [14, 151, 86, 200],
#     [40, 131, 80, 156],
#     [269, 0, 303, 37]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_A_18_treat_10_image_3.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 409},
#  {'annotations': {'bbox': [[173, 232, 196, 270], [200, 187, 269, 291]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0075_image_3.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 410},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0075_image_3.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 410},
#  {'annotations': {'bbox': [[0, 450, 84, 500],
#     [104, 446, 132, 465],
#     [30, 422, 57, 450],
#     [160, 417, 211, 456],
#     [0, 417, 33, 455],
#     [43, 404, 92, 440],
#     [95, 394, 156, 448],
#     [86, 393, 121, 416],
#     [76, 378, 120, 399],
#     [172, 355, 230, 389],
#     [82, 343, 143, 385],
#     [84, 333, 123, 352],
#     [165, 291, 239, 347],
#     [457, 186, 480, 217],
#     [9, 74, 37, 94],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_08579287db13d6f9f758_image_8.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 411},
#  {'annotations': {'bbox': [[454, 452, 479, 472],
#     [436, 413, 456, 435],
#     [407, 369, 429, 408],
#     [0, 300, 25, 336],
#     [118, 286, 135, 302],
#     [103, 248, 173, 274],
#     [0, 203, 272, 500],
#     [381, 112, 500, 247],
#     [0, 50, 32, 97],
#     [0, 0, 165, 74]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_08579287db13d6f9f758_image_8.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 411},
#  {'annotations': {'bbox': [[36, 323, 114, 402],
#     [142, 141, 200, 184],
#     [0, 131, 41, 201],
#     [104, 124, 131, 147],
#     [69, 89, 135, 130],
#     [30, 59, 74, 111],
#     [161, 44, 224, 102]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/e1_08579287db13d6f9f758_image_8.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 411},
#  {'annotations': {'bbox': [[190, 0, 500, 500], [0, 0, 210, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_A_5_treat_4_image_10.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 412},
#  {'annotations': {'bbox': [[473, 480, 500, 500],
#     [345, 465, 392, 500],
#     [329, 350, 415, 441],
#     [449, 242, 500, 396],
#     [464, 142, 500, 231],
#     [327, 86, 424, 273],
#     [469, 61, 500, 140],
#     [454, 0, 500, 57],
#     [329, 0, 409, 64],
#     [133, 0, 297, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_A_5_treat_4_image_10.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 412},
#  {'annotations': {'bbox': [[38, 416, 72, 438],
#     [5, 351, 99, 403],
#     [63, 339, 98, 361],
#     [2, 317, 36, 348]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_A_5_treat_4_image_10.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 412},
#  {'annotations': {'bbox': [[128, 256, 147, 275], [156, 0, 178, 24]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0011_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 413},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0011_image_5.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 413},
#  {'annotations': {'bbox': [[404, 432, 435, 456],
#     [311, 412, 334, 438],
#     [89, 334, 107, 355],
#     [205, 329, 243, 361],
#     [99, 286, 168, 411],
#     [219, 177, 272, 213],
#     [18, 172, 35, 194],
#     [226, 145, 245, 166],
#     [420, 141, 452, 163],
#     [256, 84, 284, 112],
#     [161, 71, 266, 148],
#     [433, 58, 450, 78]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0101_image_61.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 414},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0101_image_61.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 414},
#  {'annotations': {'bbox': [[169, 461, 189, 480],
#     [467, 365, 500, 432],
#     [453, 362, 474, 394],
#     [284, 342, 301, 359],
#     [314, 336, 356, 376],
#     [156, 329, 212, 356],
#     [379, 328, 420, 380],
#     [296, 294, 319, 320],
#     [407, 264, 439, 294],
#     [275, 262, 293, 278],
#     [267, 224, 283, 240],
#     [0, 147, 286, 384]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0072_image_24.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 415},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0072_image_24.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 415},
#  {'annotations': {'bbox': [[30, 461, 62, 500],
#     [264, 452, 319, 474],
#     [0, 450, 24, 500],
#     [140, 439, 156, 460],
#     [91, 433, 119, 463],
#     [160, 415, 179, 454],
#     [185, 413, 219, 469],
#     [385, 403, 409, 428],
#     [207, 400, 300, 462],
#     [264, 394, 355, 432],
#     [44, 386, 116, 449],
#     [118, 138, 140, 156],
#     [462, 136, 498, 159],
#     [353, 111, 370, 131],
#     [376, 108, 400, 136],
#     [224, 108, 258, 126],
#     [315, 98, 347, 116],
#     [250, 92, 272, 121],
#     [307, 32, 367, 57],
#     [101, 29, 119, 49],
#     [396, 0, 500, 104],
#     [43, 0, 62, 18]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0073_image_19.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 416},
#  {'annotations': {'bbox': [[458, 34, 485, 60],
#     [459, 0, 500, 29],
#     [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0073_image_19.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 416},
#  {'annotations': {'bbox': [[392, 479, 435, 500],
#     [369, 467, 392, 500],
#     [320, 399, 345, 419],
#     [233, 364, 252, 381],
#     [10, 350, 50, 370],
#     [85, 316, 106, 348],
#     [310, 214, 338, 248],
#     [320, 212, 500, 430],
#     [458, 158, 484, 174],
#     [272, 138, 295, 154],
#     [331, 52, 373, 91],
#     [279, 2, 307, 36],
#     [347, 0, 500, 49],
#     [0, 0, 350, 338]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0047_image_39.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 417},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0047_image_39.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 417},
#  {'annotations': {'bbox': [[27, 395, 46, 415],
#     [5, 316, 53, 347],
#     [41, 309, 63, 326],
#     [97, 272, 119, 294],
#     [14, 260, 73, 289],
#     [57, 216, 102, 270],
#     [398, 131, 481, 241],
#     [380, 129, 400, 158],
#     [401, 78, 459, 134]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0058_image_61.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 418},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0058_image_61.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 418},
#  {'annotations': {'bbox': [[434, 398, 460, 429],
#     [181, 224, 210, 250],
#     [459, 216, 476, 233],
#     [372, 190, 392, 208],
#     [467, 113, 486, 135],
#     [285, 101, 316, 121]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0008_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 419},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0008_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 419},
#  {'annotations': {'bbox': [[208, 332, 236, 348],
#     [78, 0, 500, 500],
#     [0, 0, 109, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_B_17_treat_10_image_14.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 420},
#  {'annotations': {'bbox': [[32, 401, 51, 428],
#     [345, 323, 463, 500],
#     [174, 310, 320, 500],
#     [393, 292, 454, 324],
#     [245, 270, 289, 305],
#     [241, 228, 278, 267],
#     [367, 39, 500, 311],
#     [401, 0, 445, 20],
#     [220, 0, 302, 196],
#     [11, 0, 158, 500]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_B_17_treat_10_image_14.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 420},
#  {'annotations': {'bbox': [[2, 231, 20, 264]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_B_17_treat_10_image_14.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 420},
#  {'annotations': {'bbox': [[41, 357, 72, 379],
#     [459, 338, 500, 367],
#     [338, 265, 359, 287],
#     [363, 231, 398, 252],
#     [396, 205, 478, 281],
#     [354, 153, 379, 185],
#     [319, 148, 338, 171],
#     [243, 122, 261, 144],
#     [383, 116, 435, 200],
#     [453, 82, 473, 100],
#     [480, 61, 500, 90],
#     [472, 13, 500, 32],
#     [216, 11, 244, 27],
#     [179, 5, 221, 21]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0071_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 421},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0071_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 421},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_B_2_treat_8_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 422},
#  {'annotations': {'bbox': [[68, 423, 109, 497],
#     [43, 257, 143, 416],
#     [268, 242, 284, 266],
#     [257, 224, 276, 243],
#     [205, 220, 226, 240],
#     [251, 195, 272, 224],
#     [41, 185, 60, 207],
#     [276, 160, 300, 186],
#     [73, 148, 118, 219],
#     [79, 5, 138, 144]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_B_2_treat_8_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 422},
#  {'annotations': {'bbox': [[137, 272, 266, 374]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_B_2_treat_8_image_1.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 422},
#  {'annotations': {'bbox': [[62, 0, 78, 17]], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0021_image_45.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 423},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0021_image_45.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 423},
#  {'annotations': {'bbox': [[170, 475, 189, 495], [0, 0, 500, 500]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_A_5_treat_4_image_12.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 424},
#  {'annotations': {'bbox': [[313, 356, 334, 391],
#     [144, 335, 291, 500],
#     [328, 315, 424, 388],
#     [480, 307, 500, 381],
#     [480, 255, 500, 294],
#     [474, 200, 500, 247],
#     [327, 167, 415, 272],
#     [155, 163, 256, 271],
#     [23, 90, 52, 121],
#     [471, 73, 500, 160],
#     [474, 0, 500, 75],
#     [345, 0, 400, 52],
#     [161, 0, 288, 157]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_A_5_treat_4_image_12.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 424},
#  {'annotations': {'bbox': [[212, 318, 267, 350],
#     [149, 295, 204, 350],
#     [43, 255, 71, 276],
#     [53, 205, 102, 238],
#     [5, 156, 57, 229]],
#    'bbx_mode': 1,
#    'category_id': 2},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/f1_id_A_5_treat_4_image_12.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 424},
#  {'annotations': {'bbox': [[369, 408, 395, 432],
#     [240, 403, 319, 480],
#     [452, 399, 500, 437],
#     [456, 362, 473, 378],
#     [81, 166, 120, 198],
#     [0, 148, 500, 454],
#     [482, 124, 500, 148],
#     [384, 90, 405, 107],
#     [212, 36, 255, 81],
#     [315, 20, 337, 60],
#     [47, 16, 65, 33],
#     [138, 6, 241, 150],
#     [358, 0, 495, 111]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/id_g2_2_16_image.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 425},
#  {'annotations': {'bbox': [[49, 353, 75, 376],
#     [0, 308, 500, 500],
#     [91, 300, 206, 369],
#     [441, 208, 488, 236],
#     [0, 0, 500, 255]],
#    'bbx_mode': 1,
#    'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/id_g2_2_16_image.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 425},
#  {'annotations': {'bbox': [[41, 214, 60, 238]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0061_image_22.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 426},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0061_image_22.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 426},
#  {'annotations': {'bbox': [], 'bbx_mode': 1, 'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0103_image_55.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 427},
#  {'annotations': {'bbox': [[0, 0, 500, 500]], 'bbx_mode': 1, 'category_id': 1},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0103_image_55.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 427},
#  {'annotations': {'bbox': [[0, 439, 79, 500],
#     [107, 413, 184, 500],
#     [101, 412, 120, 432],
#     [42, 400, 60, 416],
#     [143, 393, 196, 420],
#     [99, 392, 117, 413],
#     [164, 367, 188, 389],
#     [91, 359, 112, 376],
#     [483, 350, 500, 373],
#     [453, 308, 500, 335],
#     [161, 267, 188, 288],
#     [184, 265, 229, 285],
#     [35, 236, 76, 272],
#     [128, 176, 145, 199],
#     [62, 134, 318, 275],
#     [400, 32, 434, 50],
#     [50, 14, 95, 52],
#     [411, 0, 500, 41],
#     [366, 0, 410, 28],
#     [56, 0, 101, 18]],
#    'bbx_mode': 1,
#    'category_id': 0},
#   'file_name': '/data/weed_data/kfold_5ds/1/images/g1_DJI_0037_image_60.png',
#   'height': 500,
#   'width': 500,
#   'image_id': 428},
#  ...]

# %%
with open("/data/weed_data/kfold_5ds/1/bbox_dictionary_test", "w") as fp:
    json.dump(bbox_dictionary,fp)
